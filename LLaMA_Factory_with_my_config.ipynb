# %%
# !git clone https://github.com/hiyouga/LLaMA-Factory.git
# Out:
# Cloning into 'LLaMA-Factory'...
# remote: Enumerating objects: 21105, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 21105 (delta 24), reused 6 (delta 6), pack-reused 21049 (from 2)
# Receiving objects: 100% (21105/21105), 234.72 MiB | 16.93 MiB/s, done.
# Resolving deltas: 100% (15302/15302), done.

# %%
# %cd LLaMA-Factory
# Out:
# /content/LLaMA-Factory

# %%
# !pwd
# Out:
# /content/LLaMA-Factory

# %%
# !pip install -r requirements.txt
# Out:
# Ignoring transformers: markers 'python_version < "3.10"' don't match your environment
# Collecting transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2 (from -r requirements.txt (line 2))
#   Downloading transformers-4.48.2-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.7 MB/s eta 0:00:00
# Collecting datasets<=3.2.0,>=2.16.0 (from -r requirements.txt (line 3))
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: accelerate<=1.2.1,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (1.2.1)
# Collecting peft<=0.12.0,>=0.11.1 (from -r requirements.txt (line 5))
#   Downloading peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Collecting trl<=0.9.6,>=0.8.6 (from -r requirements.txt (line 6))
#   Downloading trl-0.9.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tokenizers<=0.21.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (0.21.0)
# Collecting gradio<=5.12.0,>=4.38.0 (from -r requirements.txt (line 8))
#   Downloading gradio-5.12.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (1.13.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (0.8.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (0.2.0)
# Collecting tiktoken (from -r requirements.txt (line 13))
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (4.25.6)
# Collecting uvicorn (from -r requirements.txt (line 15))
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (2.10.6)
# Collecting fastapi (from -r requirements.txt (line 17))
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Collecting sse-starlette (from -r requirements.txt (line 18))
#   Downloading sse_starlette-2.2.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (3.10.0)
# Collecting fire (from -r requirements.txt (line 20))
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 21)) (24.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (6.0.2)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 23)) (1.26.4)
# Collecting av (from -r requirements.txt (line 24))
#   Downloading av-14.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 25)) (0.10.2.post1)
# Collecting tyro<0.9.0 (from -r requirements.txt (line 26))
#   Downloading tyro-0.8.14-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2->-r requirements.txt (line 2)) (0.27.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2->-r requirements.txt (line 2)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2->-r requirements.txt (line 2)) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3)) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3))
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3))
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3))
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3)) (3.11.11)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4)) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4)) (2.5.1+cu124)
# Collecting aiofiles<24.0,>=22.0 (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (3.7.1)
# Collecting ffmpy (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.5.4 (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading gradio_client-1.5.4-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (3.1.5)
# Collecting markupsafe~=2.0 (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (3.10.15)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (11.1.0)
# Collecting pydub (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.2.2 (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading ruff-0.9.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: websockets<15.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.5.4->gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 9)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 9)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 9)) (2025.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn->-r requirements.txt (line 15)) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->-r requirements.txt (line 15)) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->-r requirements.txt (line 16)) (2.27.2)
# Collecting anyio<5.0,>=3.0 (from gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8))
#   Downloading anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 19)) (3.2.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire->-r requirements.txt (line 20)) (2.5.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->-r requirements.txt (line 25)) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r requirements.txt (line 25)) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa->-r requirements.txt (line 25)) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r requirements.txt (line 25)) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r requirements.txt (line 25)) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa->-r requirements.txt (line 25)) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->-r requirements.txt (line 25)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->-r requirements.txt (line 25)) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->-r requirements.txt (line 25)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r requirements.txt (line 25)) (1.1.0)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.11/dist-packages (from tyro<0.9.0->-r requirements.txt (line 26)) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro<0.9.0->-r requirements.txt (line 26)) (13.9.4)
# Collecting shtab>=1.5.6 (from tyro<0.9.0->-r requirements.txt (line 26))
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->-r requirements.txt (line 3)) (1.18.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (1.0.7)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->-r requirements.txt (line 25)) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->-r requirements.txt (line 25)) (4.3.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->-r requirements.txt (line 9)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro<0.9.0->-r requirements.txt (line 26)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro<0.9.0->-r requirements.txt (line 26)) (2.18.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->librosa->-r requirements.txt (line 25)) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa->-r requirements.txt (line 25)) (1.17.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4)) (3.4.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate<=1.2.1,>=0.34.0->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio<=5.12.0,>=4.38.0->-r requirements.txt (line 8)) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->-r requirements.txt (line 25)) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro<0.9.0->-r requirements.txt (line 26)) (0.1.2)
# Downloading transformers-4.48.2-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 97.6 MB/s eta 0:00:00
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 36.6 MB/s eta 0:00:00
# Downloading peft-0.12.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 27.9 MB/s eta 0:00:00
# Downloading trl-0.9.6-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.8/245.8 kB 24.5 MB/s eta 0:00:00
# Downloading gradio-5.12.0-py3-none-any.whl (57.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 MB 12.5 MB/s eta 0:00:00
# Downloading gradio_client-1.5.4-py3-none-any.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.4/321.4 kB 26.9 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.5 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.4 MB/s eta 0:00:00
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.0 MB/s eta 0:00:00
# Downloading sse_starlette-2.2.1-py3-none-any.whl (10 kB)
# Downloading av-14.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.5/39.5 MB 11.6 MB/s eta 0:00:00
# Downloading tyro-0.8.14-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 7.9 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 kB 8.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.4 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.3 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.9.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 39.1 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 6.4 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 15.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 28.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.6 MB/s eta 0:00:00
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.2 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=81d3e7cc3463ae5c19b83560a9775fd5d967bff01be55213135207e464e99ff7
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# Installing collected packages: pydub, xxhash, uvicorn, tomlkit, shtab, semantic-version, ruff, python-multipart, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, markupsafe, fsspec, fire, ffmpy, dill, av, anyio, aiofiles, tiktoken, starlette, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, tyro, sse-starlette, safehttpx, nvidia-cusolver-cu12, gradio-client, fastapi, transformers, gradio, datasets, trl, peft
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.47.1
#     Uninstalling transformers-4.47.1:
#       Successfully uninstalled transformers-4.47.1
#   Attempting uninstall: peft
#     Found existing installation: peft 0.14.0
#     Uninstalling peft-0.14.0:
#       Successfully uninstalled peft-0.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.8.0 which is incompatible.
# Successfully installed aiofiles-23.2.1 anyio-4.8.0 av-14.1.0 datasets-3.2.0 dill-0.3.8 fastapi-0.115.8 ffmpy-0.5.0 fire-0.7.0 fsspec-2024.9.0 gradio-5.12.0 gradio-client-1.5.4 markupsafe-2.1.5 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 peft-0.12.0 pydub-0.25.1 python-multipart-0.0.20 ruff-0.9.4 safehttpx-0.1.6 semantic-version-2.10.0 shtab-1.7.1 sse-starlette-2.2.1 starlette-0.45.3 tiktoken-0.8.0 tomlkit-0.13.2 transformers-4.48.2 trl-0.9.6 tyro-0.8.14 uvicorn-0.34.0 xxhash-3.5.0

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.1-py3-none-manylinux_2_24_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: torch~=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.5.1+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch~=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch~=2.0->bitsandbytes) (2.1.5)
# Downloading bitsandbytes-0.45.1-py3-none-manylinux_2_24_x86_64.whl (69.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 9.6 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.1

# %%
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-ubc9tany
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-ubc9tany
#   Resolved https://github.com/huggingface/transformers.git to commit 0de15c988b0d27758ce360adb2627e9ea99e91b3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.49.0.dev0) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.49.0.dev0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.49.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.49.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.49.0.dev0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.49.0.dev0) (2024.12.14)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.49.0.dev0-py3-none-any.whl size=10680508 sha256=b8cc2571d4bac3264510c5c8f2b9714c8e59c56fdba59737c28c3888b2d10d7f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-iv2clwax/wheels/32/4b/78/f195c684dd3a9ed21f3b39fe8f85b48df7918581b6437be143
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.2
#     Uninstalling transformers-4.48.2:
#       Successfully uninstalled transformers-4.48.2
# Successfully installed transformers-4.49.0.dev0

# %%
# !pip install -e ".[torch, metrics]"
# Out:
# Obtaining file:///content/LLaMA-Factory
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2 (from llamafactory==0.9.2.dev0)
#   Using cached transformers-4.48.2-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: datasets<=3.2.0,>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (3.2.0)
# Requirement already satisfied: accelerate<=1.2.1,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (1.2.1)
# Requirement already satisfied: peft<=0.12.0,>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.12.0)
# Requirement already satisfied: trl<=0.9.6,>=0.8.6 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.9.6)
# Requirement already satisfied: tokenizers<=0.21.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.21.0)
# Requirement already satisfied: gradio<=5.12.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (5.12.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (1.13.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.8.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.2.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.8.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (4.25.6)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.34.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (2.10.6)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.115.8)
# Requirement already satisfied: sse-starlette in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (2.2.1)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (3.10.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (24.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (6.0.2)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (1.26.4)
# Requirement already satisfied: av in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (14.1.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.10.2.post1)
# Requirement already satisfied: tyro<0.9.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.8.14)
# Requirement already satisfied: torch>=1.13.1 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (2.5.1+cu124)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (3.9.1)
# Requirement already satisfied: jieba in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.2.dev0) (0.42.1)
# Collecting rouge-chinese (from llamafactory==0.9.2.dev0)
#   Downloading rouge_chinese-1.0.3-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.2.1,>=0.34.0->llamafactory==0.9.2.dev0) (5.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.2.1,>=0.34.0->llamafactory==0.9.2.dev0) (0.27.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.2.1,>=0.34.0->llamafactory==0.9.2.dev0) (0.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (3.11.11)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (4.8.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (0.5.0)
# Requirement already satisfied: gradio-client==1.5.4 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (1.5.4)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (3.1.5)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (3.10.15)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (11.1.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (0.0.20)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (0.9.4)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (0.45.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (4.12.2)
# Requirement already satisfied: websockets<15.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.5.4->gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (14.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.2.dev0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.2.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.2.dev0) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.2.dev0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.2.dev0) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.2.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->llamafactory==0.9.2.dev0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->llamafactory==0.9.2.dev0) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->llamafactory==0.9.2.dev0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->llamafactory==0.9.2.dev0) (2.27.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.1->llamafactory==0.9.2.dev0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.1->llamafactory==0.9.2.dev0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.48.2,>=4.41.2->llamafactory==0.9.2.dev0) (2024.11.6)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.11/dist-packages (from tyro<0.9.0->llamafactory==0.9.2.dev0) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro<0.9.0->llamafactory==0.9.2.dev0) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from tyro<0.9.0->llamafactory==0.9.2.dev0) (1.7.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn->llamafactory==0.9.2.dev0) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->llamafactory==0.9.2.dev0) (0.14.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire->llamafactory==0.9.2.dev0) (2.5.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.2.dev0) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.2.dev0) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.2.dev0) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.2.dev0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.2.dev0) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.2.dev0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.2.dev0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.2.dev0) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.2.dev0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.2.dev0) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from rouge-chinese->llamafactory==0.9.2.dev0) (1.17.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (1.18.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (1.0.7)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->llamafactory==0.9.2.dev0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->llamafactory==0.9.2.dev0) (4.3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets<=3.2.0,>=2.16.0->llamafactory==0.9.2.dev0) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.2.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.2.dev0) (2.18.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->librosa->llamafactory==0.9.2.dev0) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa->llamafactory==0.9.2.dev0) (1.17.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio<=5.12.0,>=4.38.0->llamafactory==0.9.2.dev0) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->llamafactory==0.9.2.dev0) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.2.dev0) (0.1.2)
# Using cached transformers-4.48.2-py3-none-any.whl (9.7 MB)
# Downloading rouge_chinese-1.0.3-py3-none-any.whl (21 kB)
# Building wheels for collected packages: llamafactory
#   Building editable for llamafactory (pyproject.toml) ... done
#   Created wheel for llamafactory: filename=llamafactory-0.9.2.dev0-0.editable-py3-none-any.whl size=25422 sha256=c08f4a85ead19d35278c857a67dbc2057977ee7fd3ad4a5debd2c5653af63a8f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zkkmhmow/wheels/bd/34/05/1e3cb4b8f20c20631b411dc5157b4b150850c03496fa96c2c4
# Successfully built llamafactory
# Installing collected packages: rouge-chinese, transformers, llamafactory
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.49.0.dev0
#     Uninstalling transformers-4.49.0.dev0:
#       Successfully uninstalled transformers-4.49.0.dev0
# Successfully installed llamafactory-0.9.2.dev0 rouge-chinese-1.0.3 transformers-4.48.2

# %%
# !pip install liger-kernel
# Out:
# Collecting liger-kernel
#   Downloading liger_kernel-0.5.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torch>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from liger-kernel) (2.5.1+cu124)
# Requirement already satisfied: triton>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from liger-kernel) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.2->liger-kernel) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1.2->liger-kernel) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1.2->liger-kernel) (2.1.5)
# Downloading liger_kernel-0.5.2-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.2/104.2 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: liger-kernel
# Successfully installed liger-kernel-0.5.2

# %% [markdown]
# **Llama Board**

# %% [markdown]
# **Llama Factory CLI**

# %%
import os
# !GRADIO_SHARE=1 llamafactory-cli webui
# Out:
# 2025-02-05 19:01:45.706276: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738782105.956827    3250 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738782106.033522    3250 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-05 19:01:46.552762: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://82ac30e075b9fa038c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Keyboard interruption in main thread... closing server.
# Killing tunnel 0.0.0.0:7860 <> https://82ac30e075b9fa038c.gradio.live

# %%
import json

args = dict(
  stage="sft",                        # do supervised fine-tuning
  do_train=True,
  model_name_or_path="Qwen/Qwen2-VL-2B-Instruct", # use bnb-4bit-quantized Llama-3-8B-Instruct model
  dataset="mllm_demo,identity",             # use alpaca and identity datasets
  template="qwen2_vl",                     # use llama3 prompt template
  finetuning_type="lora",                   # use LoRA adapters to save memory
  lora_target="all",                     # attach LoRA adapters to all linear layers
  output_dir="qwen2vl_lora",                  # the path to save LoRA adapters
  per_device_train_batch_size=2,               # the batch size
  gradient_accumulation_steps=4,               # the gradient accumulation steps
  lr_scheduler_type="cosine",                 # use cosine learning rate scheduler
  logging_steps=10,                      # log every 10 steps
  warmup_ratio=0.1,                      # use warmup scheduler
  save_steps=1000,                      # save checkpoint every 1000 steps
  learning_rate=5e-5,                     # the learning rate
  num_train_epochs=3.0,                    # the epochs of training
  max_samples=500,                      # use 500 examples in each dataset
  max_grad_norm=1.0,                     # clip gradient norm to 1.0
  loraplus_lr_ratio=16.0,                   # use LoRA+ algorithm with lambda=16.0
  fp16=True,                         # use float16 mixed precision training
  use_liger_kernel=True,                   # use liger kernel for efficient training
)

# %%
json.dump(args, open("train_qwen2vl.json", "w", encoding="utf-8"), indent=2)

# %%
# !llamafactory-cli train train_qwen2vl.json
# Out:
# 2025-02-05 19:33:48.913938: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738784029.102386   11151 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738784029.157069   11151 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-05 19:33:49.569045: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO|2025-02-05 19:33:59] llamafactory.hparams.parser:380 >> Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: False, compute dtype: torch.float16
# [INFO|configuration_utils.py:696] 2025-02-05 19:33:59,694 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/config.json
# [INFO|configuration_utils.py:768] 2025-02-05 19:33:59,697 >> Model config Qwen2VLConfig {
#   "_name_or_path": "Qwen/Qwen2-VL-2B-Instruct",
#   "architectures": [
#     "Qwen2VLForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "image_token_id": 151655,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2_vl",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": {
#     "mrope_section": [
#       16,
#       24,
#       24
#     ],
#     "rope_type": "default",
#     "type": "default"
#   },
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "video_token_id": 151656,
#   "vision_config": {
#     "hidden_size": 1536,
#     "in_chans": 3,
#     "model_type": "qwen2_vl",
#     "spatial_patch_size": 14
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652,
#   "vision_token_id": 151654,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:33:59,807 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/vocab.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:33:59,808 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/merges.txt
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:33:59,808 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/tokenizer.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:33:59,808 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:33:59,808 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:33:59,808 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:33:59,808 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2304] 2025-02-05 19:34:00,231 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|image_processing_base.py:381] 2025-02-05 19:34:00,493 >> loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/preprocessor_config.json
# [INFO|image_processing_base.py:381] 2025-02-05 19:34:00,579 >> loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/preprocessor_config.json
# [INFO|image_processing_base.py:434] 2025-02-05 19:34:00,580 >> Image processor Qwen2VLImageProcessor {
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "Qwen2VLImageProcessor",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "max_pixels": 12845056,
#   "merge_size": 2,
#   "min_pixels": 3136,
#   "patch_size": 14,
#   "processor_class": "Qwen2VLProcessor",
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "max_pixels": 12845056,
#     "min_pixels": 3136
#   },
#   "temporal_patch_size": 2
# }
#
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:34:00,671 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/vocab.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:34:00,671 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/merges.txt
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:34:00,671 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/tokenizer.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:34:00,671 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:34:00,671 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:34:00,671 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:34:00,671 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2304] 2025-02-05 19:34:01,048 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|processing_utils.py:780] 2025-02-05 19:34:01,966 >> Processor Qwen2VLProcessor:
# - image_processor: Qwen2VLImageProcessor {
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "Qwen2VLImageProcessor",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "max_pixels": 12845056,
#   "merge_size": 2,
#   "min_pixels": 3136,
#   "patch_size": 14,
#   "processor_class": "Qwen2VLProcessor",
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "max_pixels": 12845056,
#     "min_pixels": 3136
#   },
#   "temporal_patch_size": 2
# }
#
# - tokenizer: Qwen2TokenizerFast(name_or_path='Qwen/Qwen2-VL-2B-Instruct', vocab_size=151643, model_max_length=32768, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'eos_token': '<|im_end|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )
#
# {
#   "processor_class": "Qwen2VLProcessor"
# }
#
# [INFO|2025-02-05 19:34:02] llamafactory.data.template:157 >> Add <|im_end|> to stop words.
# [INFO|2025-02-05 19:34:02] llamafactory.data.loader:157 >> Loading dataset mllm_demo.json...
# [INFO|2025-02-05 19:34:02] llamafactory.data.loader:157 >> Loading dataset identity.json...
# training example:
# input_ids:
# [151644, 8948, 198, 2610, 525, 264, 10950, 17847, 13, 151645, 198, 151644, 872, 198, 151652, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151653, 15191, 525, 807, 30, 151645, 198, 151644, 77091, 198, 6865, 2299, 45556, 323, 87552, 89, 4554, 504, 55591, 46204, 13, 151645, 198, 151644, 872, 198, 3838, 525, 807, 3730, 30, 151645, 198, 151644, 77091, 198, 6865, 525, 31589, 389, 279, 22174, 2070, 13, 151645, 198]
# inputs:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|vision_end|>Who are they?<|im_end|>
# <|im_start|>assistant
# They're Kane and Gretzka from Bayern Munich.<|im_end|>
# <|im_start|>user
# What are they doing?<|im_end|>
# <|im_start|>assistant
# They are celebrating on the soccer field.<|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, 6865, 2299, 45556, 323, 87552, 89, 4554, 504, 55591, 46204, 13, 151645, 198, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, 6865, 525, 31589, 389, 279, 22174, 2070, 13, 151645, 198]
# labels:
# They're Kane and Gretzka from Bayern Munich.<|im_end|>
# They are celebrating on the soccer field.<|im_end|>
#
# [INFO|configuration_utils.py:696] 2025-02-05 19:34:02,583 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/config.json
# [INFO|configuration_utils.py:768] 2025-02-05 19:34:02,585 >> Model config Qwen2VLConfig {
#   "_name_or_path": "Qwen/Qwen2-VL-2B-Instruct",
#   "architectures": [
#     "Qwen2VLForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "image_token_id": 151655,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2_vl",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": {
#     "mrope_section": [
#       16,
#       24,
#       24
#     ],
#     "rope_type": "default",
#     "type": "default"
#   },
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "video_token_id": 151656,
#   "vision_config": {
#     "hidden_size": 1536,
#     "in_chans": 3,
#     "model_type": "qwen2_vl",
#     "spatial_patch_size": 14
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652,
#   "vision_token_id": 151654,
#   "vocab_size": 151936
# }
#
# [INFO|modeling_utils.py:3904] 2025-02-05 19:34:02,623 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/model.safetensors.index.json
# [INFO|modeling_utils.py:1582] 2025-02-05 19:34:02,626 >> Instantiating Qwen2VLForConditionalGeneration model under default dtype torch.float16.
# [INFO|configuration_utils.py:1140] 2025-02-05 19:34:02,627 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151645
# }
#
# [INFO|modeling_utils.py:1582] 2025-02-05 19:34:02,628 >> Instantiating Qwen2VisionTransformerPretrainedModel model under default dtype torch.float16.
# [WARNING|logging.py:328] 2025-02-05 19:34:02,657 >> `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards: 100% 2/2 [00:11<00:00,  5.96s/it]
# [INFO|modeling_utils.py:4888] 2025-02-05 19:34:14,706 >> All model checkpoint weights were used when initializing Qwen2VLForConditionalGeneration.
#
# [INFO|modeling_utils.py:4896] 2025-02-05 19:34:14,706 >> All the weights of Qwen2VLForConditionalGeneration were initialized from the model checkpoint at Qwen/Qwen2-VL-2B-Instruct.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Qwen2VLForConditionalGeneration for predictions without further training.
# [INFO|configuration_utils.py:1095] 2025-02-05 19:34:14,811 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/generation_config.json
# [INFO|configuration_utils.py:1140] 2025-02-05 19:34:14,811 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": true,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "pad_token_id": 151643,
#   "temperature": 0.01,
#   "top_k": 1,
#   "top_p": 0.001
# }
#
# [INFO|2025-02-05 19:34:14] llamafactory.model.model_utils.checkpointing:157 >> Gradient checkpointing enabled.
# [INFO|2025-02-05 19:34:14] llamafactory.model.model_utils.attention:157 >> Using torch SDPA for faster training and inference.
# [INFO|2025-02-05 19:34:14] llamafactory.model.adapter:157 >> Upcasting trainable params to float32.
# [INFO|2025-02-05 19:34:14] llamafactory.model.adapter:157 >> Fine-tuning method: LoRA
# [INFO|2025-02-05 19:34:14] llamafactory.model.model_utils.misc:157 >> Found linear modules: down_proj,v_proj,gate_proj,up_proj,q_proj,o_proj,k_proj
# [INFO|2025-02-05 19:34:14] llamafactory.model.model_utils.visual:157 >> Set vision model not trainable: ['visual.patch_embed', 'visual.blocks'].
# [INFO|2025-02-05 19:34:15] llamafactory.model.loader:157 >> trainable params: 9,232,384 || all params: 2,218,217,984 || trainable%: 0.4162
# [WARNING|trainer.py:525] 2025-02-05 19:34:15,366 >> The model is not an instance of PreTrainedModel. No liger kernels will be applied.
# [INFO|trainer.py:741] 2025-02-05 19:34:15,420 >> Using auto half precision backend
# [INFO|2025-02-05 19:34:15] llamafactory.train.trainer_utils:157 >> Using LoRA+ optimizer with loraplus lr ratio 16.00.
# [INFO|trainer.py:2369] 2025-02-05 19:34:15,836 >> ***** Running training *****
# [INFO|trainer.py:2370] 2025-02-05 19:34:15,836 >>   Num examples = 97
# [INFO|trainer.py:2371] 2025-02-05 19:34:15,836 >>   Num Epochs = 3
# [INFO|trainer.py:2372] 2025-02-05 19:34:15,836 >>   Instantaneous batch size per device = 2
# [INFO|trainer.py:2375] 2025-02-05 19:34:15,836 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:2376] 2025-02-05 19:34:15,836 >>   Gradient Accumulation steps = 4
# [INFO|trainer.py:2377] 2025-02-05 19:34:15,836 >>   Total optimization steps = 36
# [INFO|trainer.py:2378] 2025-02-05 19:34:15,841 >>   Number of trainable parameters = 9,232,384
# [INFO|integration_utils.py:817] 2025-02-05 19:34:15,850 >> Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ammarabdelhady8 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Tracking run with wandb version 0.19.5
# wandb: Run data is saved locally in /content/LLaMA-Factory/wandb/run-20250205_193437-yzvvf5fs
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run qwen2vl_lora
# wandb: ⭐️ View project at https://wandb.ai/ammarabdelhady8/llamafactory
# wandb: 🚀 View run at https://wandb.ai/ammarabdelhady8/llamafactory/runs/yzvvf5fs
#   0% 0/36 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# {'loss': 1.748, 'grad_norm': 1.1930487155914307, 'learning_rate': 4.5786740307563636e-05, 'epoch': 0.82}
# {'loss': 0.8088, 'grad_norm': 1.249854564666748, 'learning_rate': 2.5e-05, 'epoch': 1.57}
# {'loss': 0.6329, 'grad_norm': 0.7581899166107178, 'learning_rate': 4.213259692436367e-06, 'epoch': 2.33}
# 100% 36/36 [01:05<00:00,  1.73s/it][INFO|trainer.py:3910] 2025-02-05 19:35:44,438 >> Saving model checkpoint to qwen2vl_lora/checkpoint-36
# [INFO|configuration_utils.py:696] 2025-02-05 19:35:44,662 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/config.json
# [INFO|configuration_utils.py:768] 2025-02-05 19:35:44,664 >> Model config Qwen2VLConfig {
#   "architectures": [
#     "Qwen2VLForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "image_token_id": 151655,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2_vl",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": {
#     "mrope_section": [
#       16,
#       24,
#       24
#     ],
#     "rope_type": "default",
#     "type": "default"
#   },
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "video_token_id": 151656,
#   "vision_config": {
#     "hidden_size": 1536,
#     "in_chans": 3,
#     "model_type": "qwen2_vl",
#     "spatial_patch_size": 14
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652,
#   "vision_token_id": 151654,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2491] 2025-02-05 19:35:44,798 >> tokenizer config file saved in qwen2vl_lora/checkpoint-36/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-02-05 19:35:44,799 >> Special tokens file saved in qwen2vl_lora/checkpoint-36/special_tokens_map.json
# [INFO|image_processing_base.py:261] 2025-02-05 19:35:45,423 >> Image processor saved in qwen2vl_lora/checkpoint-36/preprocessor_config.json
# [INFO|tokenization_utils_base.py:2491] 2025-02-05 19:35:45,432 >> tokenizer config file saved in qwen2vl_lora/checkpoint-36/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-02-05 19:35:45,434 >> Special tokens file saved in qwen2vl_lora/checkpoint-36/special_tokens_map.json
# [INFO|processing_utils.py:546] 2025-02-05 19:35:46,608 >> chat template saved in qwen2vl_lora/checkpoint-36/chat_template.json
# [INFO|trainer.py:2643] 2025-02-05 19:35:46,608 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 90.7678, 'train_samples_per_second': 3.206, 'train_steps_per_second': 0.397, 'train_loss': 0.9879859619670444, 'epoch': 2.82}
# 100% 36/36 [01:07<00:00,  1.87s/it]
# [INFO|image_processing_base.py:261] 2025-02-05 19:35:46,617 >> Image processor saved in qwen2vl_lora/preprocessor_config.json
# [INFO|tokenization_utils_base.py:2491] 2025-02-05 19:35:46,618 >> tokenizer config file saved in qwen2vl_lora/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-02-05 19:35:46,619 >> Special tokens file saved in qwen2vl_lora/special_tokens_map.json
# [INFO|processing_utils.py:546] 2025-02-05 19:35:47,565 >> chat template saved in qwen2vl_lora/chat_template.json
# [INFO|trainer.py:3910] 2025-02-05 19:35:47,566 >> Saving model checkpoint to qwen2vl_lora
# [INFO|configuration_utils.py:696] 2025-02-05 19:35:47,780 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/config.json
# [INFO|configuration_utils.py:768] 2025-02-05 19:35:47,782 >> Model config Qwen2VLConfig {
#   "architectures": [
#     "Qwen2VLForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "image_token_id": 151655,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2_vl",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": {
#     "mrope_section": [
#       16,
#       24,
#       24
#     ],
#     "rope_type": "default",
#     "type": "default"
#   },
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "video_token_id": 151656,
#   "vision_config": {
#     "hidden_size": 1536,
#     "in_chans": 3,
#     "model_type": "qwen2_vl",
#     "spatial_patch_size": 14
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652,
#   "vision_token_id": 151654,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2491] 2025-02-05 19:35:47,881 >> tokenizer config file saved in qwen2vl_lora/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-02-05 19:35:47,886 >> Special tokens file saved in qwen2vl_lora/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =     2.8163
#   total_flos               =   233269GF
#   train_loss               =      0.988
#   train_runtime            = 0:01:30.76
#   train_samples_per_second =      3.206
#   train_steps_per_second   =      0.397
# [INFO|modelcard.py:449] 2025-02-05 19:35:48,097 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Causal Language Modeling', 'type': 'text-generation'}}
# wandb:
# wandb: 🚀 View run qwen2vl_lora at: https://wandb.ai/ammarabdelhady8/llamafactory/runs/yzvvf5fs
# wandb: Find logs at: wandb/run-20250205_193437-yzvvf5fs/logs

# %%
args = dict(
  model_name_or_path="Qwen/Qwen2-VL-2B-Instruct", # use official non-quantized Llama-3-8B-Instruct model
  adapter_name_or_path="qwen2vl_lora",            # load the saved LoRA adapters
  template="qwen2_vl",                     # same to the one in training
  finetuning_type="lora",                  # same to the one in training
  export_dir="qwen2vl_2b_instruct_lora_merged",              # the path to save the merged model
  export_size=2,                       # the file shard size (in GB) of the merged model
  export_device="cpu",                    # the device used in export, can be chosen from `cpu` and `cuda`
  #export_hub_model_id="your_id/your_model",         # the Hugging Face hub ID to upload model
)

# %%
json.dump(args, open("merge_qwen2vl.json", "w", encoding="utf-8"), indent=2)

# %cd /content/LLaMA-Factory/
# Out:
# /content/LLaMA-Factory

# %%
# !llamafactory-cli export merge_qwen2vl.json
# Out:
# 2025-02-05 19:42:02.256249: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738784522.281630   13235 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738784522.289246   13235 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-05 19:42:02.311337: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO|configuration_utils.py:696] 2025-02-05 19:42:10,152 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/config.json
# [INFO|configuration_utils.py:768] 2025-02-05 19:42:10,154 >> Model config Qwen2VLConfig {
#   "_name_or_path": "Qwen/Qwen2-VL-2B-Instruct",
#   "architectures": [
#     "Qwen2VLForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "image_token_id": 151655,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2_vl",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": {
#     "mrope_section": [
#       16,
#       24,
#       24
#     ],
#     "rope_type": "default",
#     "type": "default"
#   },
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "video_token_id": 151656,
#   "vision_config": {
#     "hidden_size": 1536,
#     "in_chans": 3,
#     "model_type": "qwen2_vl",
#     "spatial_patch_size": 14
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652,
#   "vision_token_id": 151654,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:10,240 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/vocab.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:10,240 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/merges.txt
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:10,240 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/tokenizer.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:10,240 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:10,240 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:10,240 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:10,240 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2304] 2025-02-05 19:42:10,597 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|image_processing_base.py:381] 2025-02-05 19:42:10,876 >> loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/preprocessor_config.json
# [INFO|image_processing_base.py:381] 2025-02-05 19:42:10,967 >> loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/preprocessor_config.json
# [INFO|image_processing_base.py:434] 2025-02-05 19:42:10,968 >> Image processor Qwen2VLImageProcessor {
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "Qwen2VLImageProcessor",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "max_pixels": 12845056,
#   "merge_size": 2,
#   "min_pixels": 3136,
#   "patch_size": 14,
#   "processor_class": "Qwen2VLProcessor",
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "max_pixels": 12845056,
#     "min_pixels": 3136
#   },
#   "temporal_patch_size": 2
# }
#
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:11,056 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/vocab.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:11,056 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/merges.txt
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:11,056 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/tokenizer.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:11,056 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:11,057 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:11,057 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2034] 2025-02-05 19:42:11,057 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2304] 2025-02-05 19:42:11,410 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|processing_utils.py:780] 2025-02-05 19:42:12,330 >> Processor Qwen2VLProcessor:
# - image_processor: Qwen2VLImageProcessor {
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "Qwen2VLImageProcessor",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "max_pixels": 12845056,
#   "merge_size": 2,
#   "min_pixels": 3136,
#   "patch_size": 14,
#   "processor_class": "Qwen2VLProcessor",
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "max_pixels": 12845056,
#     "min_pixels": 3136
#   },
#   "temporal_patch_size": 2
# }
#
# - tokenizer: Qwen2TokenizerFast(name_or_path='Qwen/Qwen2-VL-2B-Instruct', vocab_size=151643, model_max_length=32768, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'eos_token': '<|im_end|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )
#
# {
#   "processor_class": "Qwen2VLProcessor"
# }
#
# [INFO|2025-02-05 19:42:12] llamafactory.data.template:157 >> Add <|im_end|> to stop words.
# [INFO|configuration_utils.py:696] 2025-02-05 19:42:12,466 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/config.json
# [INFO|configuration_utils.py:768] 2025-02-05 19:42:12,467 >> Model config Qwen2VLConfig {
#   "_name_or_path": "Qwen/Qwen2-VL-2B-Instruct",
#   "architectures": [
#     "Qwen2VLForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "image_token_id": 151655,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2_vl",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": {
#     "mrope_section": [
#       16,
#       24,
#       24
#     ],
#     "rope_type": "default",
#     "type": "default"
#   },
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "video_token_id": 151656,
#   "vision_config": {
#     "hidden_size": 1536,
#     "in_chans": 3,
#     "model_type": "qwen2_vl",
#     "spatial_patch_size": 14
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652,
#   "vision_token_id": 151654,
#   "vocab_size": 151936
# }
#
# [INFO|2025-02-05 19:42:12] llamafactory.model.patcher:157 >> Using KV cache for faster generation.
# [INFO|modeling_utils.py:3904] 2025-02-05 19:42:12,508 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/model.safetensors.index.json
# [INFO|modeling_utils.py:1582] 2025-02-05 19:42:12,510 >> Instantiating Qwen2VLForConditionalGeneration model under default dtype torch.bfloat16.
# [INFO|configuration_utils.py:1140] 2025-02-05 19:42:12,512 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151645
# }
#
# [INFO|modeling_utils.py:1582] 2025-02-05 19:42:12,512 >> Instantiating Qwen2VisionTransformerPretrainedModel model under default dtype torch.bfloat16.
# [WARNING|logging.py:328] 2025-02-05 19:42:12,533 >> `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards: 100% 2/2 [00:00<00:00,  2.48it/s]
# [INFO|modeling_utils.py:4888] 2025-02-05 19:42:13,483 >> All model checkpoint weights were used when initializing Qwen2VLForConditionalGeneration.
#
# [INFO|modeling_utils.py:4896] 2025-02-05 19:42:13,483 >> All the weights of Qwen2VLForConditionalGeneration were initialized from the model checkpoint at Qwen/Qwen2-VL-2B-Instruct.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Qwen2VLForConditionalGeneration for predictions without further training.
# [INFO|configuration_utils.py:1095] 2025-02-05 19:42:13,583 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-VL-2B-Instruct/snapshots/895c3a49bc3fa70a340399125c650a463535e71c/generation_config.json
# [INFO|configuration_utils.py:1140] 2025-02-05 19:42:13,583 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": true,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "pad_token_id": 151643,
#   "temperature": 0.01,
#   "top_k": 1,
#   "top_p": 0.001
# }
#
# [INFO|2025-02-05 19:42:13] llamafactory.model.model_utils.attention:157 >> Using torch SDPA for faster training and inference.
# [INFO|2025-02-05 19:42:31] llamafactory.model.adapter:157 >> Merged 1 adapter(s).
# [INFO|2025-02-05 19:42:31] llamafactory.model.adapter:157 >> Loaded adapter(s): qwen2vl_lora
# [INFO|2025-02-05 19:42:31] llamafactory.model.loader:157 >> all params: 2,208,985,600
# [INFO|2025-02-05 19:42:31] llamafactory.train.tuner:157 >> Convert model dtype to: torch.bfloat16.
# [INFO|configuration_utils.py:420] 2025-02-05 19:42:31,834 >> Configuration saved in qwen2vl_2b_instruct_lora_merged/config.json
# [INFO|configuration_utils.py:909] 2025-02-05 19:42:31,834 >> Configuration saved in qwen2vl_2b_instruct_lora_merged/generation_config.json
# [INFO|modeling_utils.py:2996] 2025-02-05 19:43:03,096 >> The model is bigger than the maximum size per checkpoint (2GB) and is going to be split in 3 checkpoint shards. You can find where each parameters has been saved in the index located at qwen2vl_2b_instruct_lora_merged/model.safetensors.index.json.
# [INFO|tokenization_utils_base.py:2491] 2025-02-05 19:43:03,151 >> tokenizer config file saved in qwen2vl_2b_instruct_lora_merged/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-02-05 19:43:03,152 >> Special tokens file saved in qwen2vl_2b_instruct_lora_merged/special_tokens_map.json
# [INFO|image_processing_base.py:261] 2025-02-05 19:43:03,385 >> Image processor saved in qwen2vl_2b_instruct_lora_merged/preprocessor_config.json
# [INFO|tokenization_utils_base.py:2491] 2025-02-05 19:43:03,674 >> tokenizer config file saved in qwen2vl_2b_instruct_lora_merged/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-02-05 19:43:03,675 >> Special tokens file saved in qwen2vl_2b_instruct_lora_merged/special_tokens_map.json
# [INFO|processing_utils.py:546] 2025-02-05 19:43:04,448 >> chat template saved in qwen2vl_2b_instruct_lora_merged/chat_template.json

# %%
final_model_path = "/content/LLaMA-Factory/qwen2vl_2b_instruct_lora_merged"

# %%
hf_model_repo = "MoRa2001/QWEN_2b_instruct_LORA-FT"

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from huggingface_hub import HfApi, HfFolder, Repository

# %%
# Create an instance of HfApi
api = HfApi()

# %%
api.upload_folder(
    folder_path=final_model_path,    # The folder containing the model files
    repo_id=hf_model_repo,                # Your authentication token
    commit_message="Initial model upload"  # Optional commit message
)
# Out:
# model-00001-of-00003.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/429M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/MoRa2001/QWEN_2b_instruct_LORA-FT/commit/4413fa87319b7cd7e09d90aca22f099fbabd41b8', commit_message='Initial model upload', commit_description='', oid='4413fa87319b7cd7e09d90aca22f099fbabd41b8', pr_url=None, repo_url=RepoUrl('https://huggingface.co/MoRa2001/QWEN_2b_instruct_LORA-FT', endpoint='https://huggingface.co', repo_type='model', repo_id='MoRa2001/QWEN_2b_instruct_LORA-FT'), pr_revision=None, pr_num=None)

# %%
print(f"Model pushed to: {hf_model_repo}")
